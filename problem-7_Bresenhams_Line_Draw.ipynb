# %%
import turtle

# =============================
# Helper Functions
# =============================


def draw_pixel(pen, x, y, color="black"):
    pen.penup()
    pen.goto(x, y)
    pen.dot(4, color)
    pen.pendown()


def bresenham_line(pen, x1, y1, x2, y2, color):
    # Ensure left-to-right drawing
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1
    dx = x2 - x1
    dy = abs(y2 - y1)
    p = 2 * dy - dx

    y = y1
    for x in range(x1, x2 + 1):
        draw_pixel(pen, x, y, color)
        if p >= 0:
            p += 2 * (dy - dx)
            y += 1 if y1 < y2 else -1
        else:
            p += 2 * dy


def draw_axes(pen, width, height):
    pen.pencolor("gray")
    # X-axis
    pen.penup()
    pen.goto(-width//2, 0)
    pen.pendown()
    pen.goto(width//2, 0)
    pen.write("X", align="center", font=("Arial", 12, "normal"))

    # Y-axis
    pen.penup()
    pen.goto(0, -height//2)
    pen.pendown()
    pen.goto(0, height//2)
    pen.write("Y", align="center", font=("Arial", 12, "normal"))
    pen.penup()

# =============================
# Main Program
# =============================


# screen setup
WIDTH, HEIGHT = 800, 600
screen = turtle.Screen()
screen.title("Bresenham Line Drawing with Turtle")
screen.setup(width=WIDTH, height=HEIGHT)
screen.bgcolor("white")
screen.tracer(5)

# pen setup
pen = turtle.Turtle()
pen.speed(1)
pen.pensize(2)
pen.pencolor("black")

# Draw axes for reference
draw_axes(pen, WIDTH, HEIGHT)

# Draw lines using Bresenham algorithm
lines = [
    ((-200, -100), (200, 100)),
    ((-200, 100), (200, -100))
    
]

for (start, end) in lines:
    x0, y0 = start
    x1, y1 = end
    bresenham_line(pen, x0, y0, x1, y1, color="blue")

pen.hideturtle()
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3429, in RawTurtle.dot(self, size, *color)
#    3428     self.pencolor(color)
# -> 3429     self.forward(0)
#    3430 finally:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1635, in TNavigator.forward(self, distance)
#    1615 """Move the turtle forward by the specified distance.
#    1616
#    1617 Aliases: forward | fd
#    (...)
#    1633 (-50.00,0.00)
#    1634 """
# -> 1635 self._go(distance)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:1596, in TNavigator._go(self, distance)
#    1595 ende = self._position + self._orient * distance
# -> 1596 self._goto(ende)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3199, in RawTurtle._goto(self, end)
#    3195 screen = self.screen
#    3196 undo_entry = ("go", self._position, end, go_modes,
#    3197               (self.currentLineItem,
#    3198               self.currentLine[:],
# -> 3199               screen._pointlist(self.currentLineItem),
#    3200               self.items[:])
#    3201               )
#    3202 if self.undobuffer:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:744, in TurtleScreenBase._pointlist(self, item)
#     737 """returns list of coordinate-pairs of points of item
#     738 Example (for insiders):
#     739 >>> from turtle import *
#    (...)
#     742 (9.9999999999999982, 0.0)]
#     743 >>> """
# --> 744 cl = self.cv.coords(item)
#     745 pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#
# File <string>:1, in coords(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py:2966, in Canvas.coords(self, *args)
#    2963 args = _flatten(args)
#    2964 return [self.tk.getdouble(x) for x in
#    2965                    self.tk.splitlist(
# -> 2966            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"
#
# During handling of the above exception, another exception occurred:
#
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 83
#      81     x0, y0 = start
#      82     x1, y1 = end
# ---> 83     bresenham_line(pen, x0, y0, x1, y1, color="blue")
#      85 pen.hideturtle()
#      86 turtle.done()
#
# Cell In[1], line 26, in bresenham_line(pen, x1, y1, x2, y2, color)
#      24 y = y1
#      25 for x in range(x1, x2 + 1):
# ---> 26     draw_pixel(pen, x, y, color)
#      27     if p >= 0:
#      28         p += 2 * (dy - dx)
#
# Cell In[1], line 11, in draw_pixel(pen, x, y, color)
#       9 pen.penup()
#      10 pen.goto(x, y)
# ---> 11 pen.dot(4, color)
#      12 pen.pendown()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3431, in RawTurtle.dot(self, size, *color)
#    3429     self.forward(0)
#    3430 finally:
# -> 3431     self.pen(pen)
#    3432 if self.undobuffer:
#    3433     self.undobuffer.cumulate = False
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:2432, in TPen.pen(self, pen, **pendict)
#    2430         newLine = True
#    2431 if newLine:
# -> 2432     self._newLine()
#    2433 if "pendown" in p:
#    2434     self._drawing = p["pendown"]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:3332, in RawTurtle._newLine(self, usePos)
#    3330     self.items.append(self.currentLineItem)
#    3331 else:
# -> 3332     self.screen._drawline(self.currentLineItem, top=True)
#    3333 self.currentLine = []
#    3334 if usePos:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\turtle.py:544, in TurtleScreenBase._drawline(self, lineitem, coordlist, fill, width, top)
#     542     self.cv.itemconfigure(lineitem, width=width)
#     543 if top:
# --> 544     self.cv.tag_raise(lineitem)
#
# File <string>:1, in tag_raise(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py:3142, in Canvas.tag_raise(self, *args)
#    3139 def tag_raise(self, *args):
#    3140     """Raise an item TAGORID given in ARGS
#    3141     (optional above another item)."""
# -> 3142     self.tk.call((self._w, 'raise') + args)
#
# TclError: invalid command name ".!canvas"
